# %%
import requests
import pandas as pd
import os

def get_openalex_data(year):
    url = f"https://api.openalex.org/works?filter=from_publication_date:{year}-01-01,to_publication_date:{year}-12-31&per-page=200"
    r = requests.get(url).json()
    return r["results"]

all_data = []
for year in range(2019, 2026):
    data = get_openalex_data(year)
    for item in data:
        # Safely get 'journal' name
        journal_name = item.get("host_venue", {}).get("display_name")

        # Safely get 'field' name
        field_name = None
        concepts = item.get("concepts")
        if concepts and isinstance(concepts, list) and len(concepts) > 0:
            field_name = concepts[0].get("display_name")

        # Safely get 'open_access' status
        open_access_status = item.get("open_access", {}).get("is_oa")

        # Safely get 'abstract'
        abstract_inverted_index = item.get("abstract_inverted_index")
        abstract_text = None
        if abstract_inverted_index:
            # Reconstruct abstract from inverted index if available
            words_by_position = {}
            for word, positions in abstract_inverted_index.items():
                for pos in positions:
                    words_by_position[pos] = word
            # Sort words by their original position and join them
            abstract_text = " ".join(words_by_position[pos] for pos in sorted(words_by_position.keys()))

        all_data.append({
            "paper_id": item["id"],
            "title": item["title"],
            "year": year,
            "citations": item["cited_by_count"],
            "journal": journal_name,
            "field": field_name,
            "open_access": open_access_status,
            "abstract": abstract_text
        })

df = pd.DataFrame(all_data)

# Create the directory if it doesn't exist
os.makedirs('data_raw', exist_ok=True)

df.to_csv("data_raw/openalex_base.csv", index=False)

# %%
ai_keywords = [
    "chatgpt",
    "generative ai",
    "large language model",
    "llm",
    "ai-assisted",
    "gpt"
]

def label_ai(text):
    if text is None:
        return 0
    text = text.lower()
    return int(any(k in text for k in ai_keywords))

df["AI_assisted"] = df["abstract"].apply(label_ai)

# %%
import textstat
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

def nlp_features(text):
    if text is None:
        return {
            "flesch": None,
            "fog": None,
            "sentence_len": None,
            "lexical_diversity": None
        }
    try:
        return {
            "flesch": textstat.flesch_reading_ease(text),
            "fog": textstat.gunning_fog(text),
            "sentence_len": len(word_tokenize(text)) / max(1, len(sent_tokenize(text))),
            "lexical_diversity": len(set(word_tokenize(text))) / max(1, len(word_tokenize(text)))
        }
    except ZeroDivisionError:
        # Handle cases where sent_tokenize might return an empty list or other edge cases
        return {
            "flesch": None,
            "fog": None,
            "sentence_len": None,
            "lexical_diversity": None
        }

# %%
# !pip install textstat nltk
# Out:
# Collecting textstat
#   Downloading textstat-0.7.12-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from textstat) (75.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)
# Downloading textstat-0.7.12-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.6/176.6 kB 7.2 MB/s eta 0:00:00
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.2 MB/s eta 0:00:00
# Installing collected packages: pyphen, textstat
# Successfully installed pyphen-0.17.2 textstat-0.7.12

# %%
import statsmodels.formula.api as smf

df["Post"] = (df["year"] >= 2022).astype(int)
df["interaction"] = df["AI_assisted"] * df["Post"]

# Temporarily remove C(field) to diagnose the error
model = smf.ols(
    "citations ~ AI_assisted + Post + interaction + open_access",
    data=df
).fit(cov_type="HC3")

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              citations   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     9.147
# Date:                Fri, 23 Jan 2026   Prob (F-statistic):           2.70e-07
# Time:                        10:40:52   Log-Likelihood:                -15983.
# No. Observations:                1400   AIC:                         3.198e+04
# Df Residuals:                    1395   BIC:                         3.200e+04
# Df Model:                           4
# Covariance Type:                  HC3
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            6489.9277    858.087      7.563      0.000    4808.108    8171.747
# open_access[T.True]  1674.1527    741.338      2.258      0.024     221.157    3127.149
# AI_assisted         -3705.0803   7.24e+04     -0.051      0.959   -1.46e+05    1.38e+05
# Post                -5416.9006   1293.723     -4.187      0.000   -7952.550   -2881.251
# interaction          3489.6953   7.24e+04      0.048      0.962   -1.38e+05    1.45e+05
# ==============================================================================
# Omnibus:                     3895.961   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         85863297.001
# Skew:                          33.762   Prob(JB):                         0.00
# Kurtosis:                    1214.356   Cond. No.                         73.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
df["event_time"] = df["year"] - 2022

# %%
model_fe = smf.ols(
    "citations ~ AI_assisted + C(paper_id) + C(year)",
    data=df
).fit()

# %%
df_nlp_features = df['abstract'].apply(nlp_features).apply(pd.Series)
df = pd.concat([df, df_nlp_features], axis=1)

m1 = smf.ols("flesch ~ AI_assisted", data=df).fit()
m2 = smf.ols("citations ~ flesch + AI_assisted", data=df).fit()

# %%
import pandas as pd

# Group by AI_assisted and calculate statistics
summary_stats = df.groupby('AI_assisted').agg(
    avg_citations=('citations', 'mean'),
    median_citations=('citations', 'median'),
    open_access_rate=('open_access', lambda x: x.sum() / len(x))
).round(2)

# Rename AI_assisted column for clarity
summary_stats.rename(index={0: 'Non-AI assisted', 1: 'AI-assisted'}, inplace=True)

print("Makale İstatistikleri (AI ve Non-AI olarak):")
print(summary_stats)

print("\nOrtalama yazar sayısı ve tekrar baskı oranı verileri mevcut değildir.")
# Out:
# Makale İstatistikleri (AI ve Non-AI olarak):
#                  avg_citations  median_citations  open_access_rate
# AI_assisted
# Non-AI assisted        4594.21            2523.0              0.68
# AI-assisted            2226.21            1241.0              0.79
#
# Ortalama yazar sayısı ve tekrar baskı oranı verileri mevcut değildir.

# %%
# Toplam makale sayısı
N = len(df)
print(f"Toplam makale sayısı: N = {N}")

# AI-assisted makale sayısı
N_AI = df['AI_assisted'].sum()
print(f"AI-assisted makale sayısı: N_AI = {N_AI}")

# Non-AI makale sayısı
N_nonAI = N - N_AI
print(f"Non-AI makale sayısı: N_nonAI = {N_nonAI}")

# Yıl aralığı
min_year = df['year'].min()
max_year = df['year'].max()
print(f"Yıllar: {min_year}–{max_year}")
# Out:
# Toplam makale sayısı: N = 1400
# AI-assisted makale sayısı: N_AI = 43
# Non-AI makale sayısı: N_nonAI = 1357
# Yıllar: 2019–2025

# %%
print(m1.summary())
print(m2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 flesch   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                  0.001902
# Date:                Fri, 23 Jan 2026   Prob (F-statistic):              0.965
# Time:                        10:51:41   Log-Likelihood:                -4314.3
# No. Observations:                 889   AIC:                             8633.
# Df Residuals:                     887   BIC:                             8642.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      17.9553      1.067     16.826      0.000      15.861      20.050
# AI_assisted     0.2116      4.852      0.044      0.965      -9.311       9.734
# ==============================================================================
# Omnibus:                     1287.375   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           544909.398
# Skew:                          -7.894   Prob(JB):                         0.00
# Kurtosis:                     123.256   Cond. No.                         4.67
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              citations   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.4009
# Date:                Fri, 23 Jan 2026   Prob (F-statistic):              0.670
# Time:                        10:51:41   Log-Likelihood:                -10350.
# No. Observations:                 889   AIC:                         2.071e+04
# Df Residuals:                     886   BIC:                         2.072e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept    4635.5048   1088.843      4.257      0.000    2498.493    6772.516
# flesch         18.7666     29.830      0.629      0.529     -39.779      77.312
# AI_assisted -2750.2253   4310.495     -0.638      0.524   -1.12e+04    5709.746
# ==============================================================================
# Omnibus:                     2309.325   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         22891781.622
# Skew:                          27.319   Prob(JB):                         0.00
# Kurtosis:                     787.229   Cond. No.                         167.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# The previous code was a syntax error. If you intended to run a regression with fixed effects,
# you might need to use a format similar to this, assuming 'citations_it', 'AI_it' are column names
# and 'paper_id' and 'year' are the variables for fixed effects.
# import numpy as np
# model_fixed_effects = smf.ols("np.log(1 + citations) ~ AI_assisted + C(paper_id) + C(year)", data=df).fit()
# print(model_fixed_effects.summary())

# %%
import numpy as np
import statsmodels.formula.api as smf

df["log_citations"] = np.log(1 + df["citations"])

model_fe = smf.ols(
    "log_citations ~ AI_assisted + C(paper_id) + C(year)",
    data=df
).fit()

print(model_fe.summary())
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_citations   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Fri, 23 Jan 2026   Prob (F-statistic):                nan
# Time:                        11:07:18   Log-Likelihood:                 39164.
# No. Observations:                1400   AIC:                        -7.553e+04
# Df Residuals:                       0   BIC:                        -6.819e+04
# Df Model:                        1399
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           8.4233        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W117731346]      0.4592        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W1481388508]    -0.8921        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W1484272304]    -0.1665        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W1488663080]    -0.4186        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/
inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409229284]    -0.7737        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409293301]    -0.9094        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409430637]    -0.5805        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409458169]    -0.4257        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409483458]    -0.3268        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409530112]    -0.2488        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409781688]    -0.7687        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409901056]    -0.7242        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409963211]    -0.2548        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4409980681]    -0.8640        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4410277932]    -0.7737        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4410436240]    -0.2280        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4410437148]    -0.9270        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4410611457]     0.2253        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4410734662]    -0.4585        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4411096100]     1.2354        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4411160871]     0.0069        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4411403346]    -0.8234        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4411969078]    -0.6232        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4413004164]    -0.6320        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4413467052]    -0.7242        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W4414243662]    -0.9211        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W48809960]       0.7695        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W563837578]     -0.8367        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W571572828]     -0.2812        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W58517354]      -0.4127        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W585478725]     -0.2105        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W589083708]     -0.3781        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W589207856]     -0.1543        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W605681562]     -0.9211        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W613851713]      1.3897        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W614933755]     -0.2428        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W616691361]     -0.8529        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W624047034]     -0.6453        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W626957649]     -0.2545        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W627355145]     -0.6956        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W627731145]     -0.0730        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W628120085]     -0.6956        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W630162528]     -0.0311        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W635671516]     -0.8152        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W636562718]      0.2584        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W645599348]      0.1121        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W646328982]     -0.0857        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W651976676]      0.0307        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W66887941]      -0.0831        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W71228264]       0.8572        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W77753788]      -0.2974        inf         -0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W850294230]      0.3397        inf          0        nan         nan         nan
# C(paper_id)[T.https://openalex.org/W88864901]      -0.4702        inf         -0        nan         nan         nan
# C(year)[T.2020]                                     0.4086        inf          0        nan         nan         nan
# C(year)[T.2021]                                    -0.1414        inf         -0        nan         nan         nan
# C(year)[T.2022]                                    -0.1518        inf         -0        nan         nan         nan
# C(year)[T.2023]                                    -0.9587        inf         -0        nan         nan         nan
# C(year)[T.2024]                                    -1.2647        inf         -0        nan         nan         nan
# C(year)[T.2025]                                    -2.3664        inf         -0        nan         nan         nan
# AI_assisted                                         0.0895        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                      603.425   Durbin-Watson:                   0.462
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           381962.803
# Skew:                           0.506   Prob(JB):                         0.00
# Kurtosis:                      83.913   Cond. No.                         563.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.

# %%
import numpy as np
import statsmodels.formula.api as smf

df["log_citations"] = np.log(1 + df["citations"])

# Removing C(field) as it causes issues with the F-test calculation
model_main = smf.ols(
    "log_citations ~ AI_assisted + C(year) + open_access",
    data=df
).fit(cov_type="HC3")

print(model_main.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_citations   R-squared:                       0.637
# Model:                            OLS   Adj. R-squared:                  0.635
# Method:                 Least Squares   F-statistic:                     245.0
# Date:                Fri, 23 Jan 2026   Prob (F-statistic):          3.20e-259
# Time:                        11:17:05   Log-Likelihood:                -1401.9
# No. Observations:                1400   AIC:                             2822.
# Df Residuals:                    1391   BIC:                             2869.
# Df Model:                           8
# Covariance Type:                  HC3
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               8.4433      0.041    203.725      0.000       8.362       8.525
# C(year)[T.2020]         0.3348      0.056      5.974      0.000       0.225       0.445
# C(year)[T.2021]        -0.2097      0.056     -3.722      0.000      -0.320      -0.099
# C(year)[T.2022]        -0.6645      0.054    -12.351      0.000      -0.770      -0.559
# C(year)[T.2023]        -1.0307      0.058    -17.783      0.000      -1.144      -0.917
# C(year)[T.2024]        -1.3356      0.059    -22.522      0.000      -1.452      -1.219
# C(year)[T.2025]        -2.4301      0.076    -32.183      0.000      -2.578      -2.282
# open_access[T.True]     0.0669      0.038      1.771      0.077      -0.007       0.141
# AI_assisted             0.0986      0.138      0.713      0.476      -0.172       0.370
# ==============================================================================
# Omnibus:                      671.500   Durbin-Watson:                   0.200
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4114.933
# Skew:                           2.182   Prob(JB):                         0.00
# Kurtosis:                      10.176   Cond. No.                         9.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity robust (HC3)

# %%
import statsmodels.formula.api as smf

models = {
    "Flesch": "flesch ~ AI_assisted + C(year) + C(field)",
    "Fog": "fog ~ AI_assisted + C(year) + C(field)",
    "SentenceLength": "sentence_len ~ AI_assisted + C(year) + C(field)"
}

results = {}

for name, formula in models.items():
    model = smf.ols(formula, data=df).fit(cov_type="HC3")
    coef = model.params["AI_assisted"]
    se = model.bse["AI_assisted"]
    p = model.pvalues["AI_assisted"]
    results[name] = (coef, se, p)

for k, v in results.items():
    print(k, "→ β:", v[0], "SE:", v[1], "p:", v[2])
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:2014: RuntimeWarning: divide by zero encountered in divide
#   self.het_scale = (self.wresid / (1 - h))**2
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1971: RuntimeWarning: invalid value encountered in multiply
#   scale[:, None] * self.model.pinv_wexog.T)
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:2014: RuntimeWarning: divide by zero encountered in divide
#   self.het_scale = (self.wresid / (1 - h))**2
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1971: RuntimeWarning: invalid value encountered in multiply
#   scale[:, None] * self.model.pinv_wexog.T)
# Flesch → β: 3.742681972171127 SE: inf p: 1.0
# Fog → β: -0.35717864934265803 SE: inf p: 1.0
# SentenceLength → β: -1.7026506380626867 SE: inf p: 1.0
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:2014: RuntimeWarning: divide by zero encountered in divide
#   self.het_scale = (self.wresid / (1 - h))**2
# /usr/local/lib/python3.12/dist-packages/statsmodels/regression/linear_model.py:1971: RuntimeWarning: invalid value encountered in multiply
#   scale[:, None] * self.model.pinv_wexog.T)

# %%
models = {
    "Flesch": "flesch ~ AI_assisted + C(year)",
    "Fog": "fog ~ AI_assisted + C(year)",
    "SentenceLength": "sentence_len ~ AI_assisted + C(year)"
}

for name, formula in models.items():
    model = smf.ols(formula, data=df).fit()
    print("\n", name)
    print("β:", model.params["AI_assisted"])
    print("SE:", model.bse["AI_assisted"])
    print("p:", model.pvalues["AI_assisted"])
# Out:
#  Flesch
# β: 1.920373951295227
# SE: 5.024898194867221
# p: 0.7024261706025542
#
#  Fog
# β: -0.5238355149012883
# SE: 1.5250397936326232
# p: 0.7313120149796499
#
#  SentenceLength
# β: -2.063417018900648
# SE: 4.528962562205764
# p: 0.6487864696831747
